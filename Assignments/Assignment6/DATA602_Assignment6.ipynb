# %% [markdown]
# # DATA 602: Assignment 6

# %%
import pandas as pd

# %% [markdown]
# Datasets being used to complete this assignment:
#
# * data602sps Github data files
#     - salarydata.csv
#     - GOOG.csv
#
# * Datasets found online
#     - Highest Holywood Grossing Movies.csv (https://www.kaggle.com/datasets/sanjeetsinghnaik/top-1000-highest-grossing-movies?select=Highest+Holywood+Grossing+Movies.csv)
#     - spotify_top50_2021.csv (https://www.kaggle.com/datasets/equinxx/spotify-top-50-songs-in-2021)

# %% [markdown]
# ## Question 1
#
# **Load your dataset into python using the pandas library and save data into a
# dataframe named dfi (where i is one of your datasets, for a total of 4).**

# %%
# salarydata.csv
df1 = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/salarydata.csv')

# GOOG.csv
df2 = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv')

# Highest Holywood Grossing Movies.csv
df3 = pd.read_csv('https://raw.githubusercontent.com/SaneSky109/DATA602/main/Assignments/Assignment6/Highest%20Holywood%20Grossing%20Movies.csv')

# spotify_top50_2021.csv
df4 = pd.read_csv('https://raw.githubusercontent.com/SaneSky109/DATA602/main/Assignments/Assignment6/spotify_top50_2021.csv')

# %% [markdown]
# ## Question 2
#
# **Preview your data by calling your dataframe’s name. How many columns and rows
# do you see?**

# %% [markdown]
# ### df1

# %% [markdown]
# The salarydata.csv dataset has 51 rows and 3 columns, but 1 column contains all NaN rows. This is due to the raw data having a comma at the end of each line while also being comma separated.

# %%
# salarydata.csv
df1
# Out:
#                    Sate  2018 Mean Annual Wage  Unnamed: 2
# 0               Alabama                 90,620         NaN
# 1                 Alaska                99,180         NaN
# 2                Arizona                88,800         NaN
# 3               Arkansas                81,430         NaN
# 4             California                97,110         NaN
# 5               Colorado                82,560         NaN
# 6            Connecticut                96,010         NaN
# 7               Delaware                93,880         NaN
# 8   District of Columbia                89,880         NaN
# 9                Florida                87,410         NaN
# 10               Georgia                86,320         NaN
# 11                Hawaii                90,540         NaN
# 12                 Idaho                77,700         NaN
# 13              IIIinois                90,690         NaN
# 14               lndiana                83,680         NaN
# ...

# %% [markdown]
# I will drop the NaN row as it is not providing any meaningful information. This will leave 50 rows and 2 columns.

# %%
# remove column
df1 = df1.drop(['Unnamed: 2'], axis = 1)

# print df1
df1
# Out:
#                    Sate  2018 Mean Annual Wage
# 0               Alabama                 90,620
# 1                 Alaska                99,180
# 2                Arizona                88,800
# 3               Arkansas                81,430
# 4             California                97,110
# 5               Colorado                82,560
# 6            Connecticut                96,010
# 7               Delaware                93,880
# 8   District of Columbia                89,880
# 9                Florida                87,410
# 10               Georgia                86,320
# 11                Hawaii                90,540
# 12                 Idaho                77,700
# 13              IIIinois                90,690
# 14               lndiana                83,680
# 15                  lowa                82,960
# 16                Kansas                85,250
# 17              Kentucky                84,630
# 18             Louisiana                89,860
# ...

# %% [markdown]
# ### df2

# %% [markdown]
# The GOOG.csv file contains 1258 rows and 7 columns related to the Google stock.

# %%
# GOOG.csv
df2
# Out:
#             Date         Open         High          Low        Close  \
# 0     2014-06-24   562.099304   569.514526   557.942139   561.532410
# 1     2014-06-25   562.168884   576.788513   562.129089   575.485657
# 2     2014-06-26   577.822815   579.264893   568.722839   572.850159
# 3     2014-06-27   574.023682   576.698975   570.662170   574.083374
# 4     2014-06-30   575.495605   576.400635   571.606995   572.134094
# ...          ...          ...          ...          ...          ...
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 0      561.532410  2213200
# 1      575.485657  1974700
# 2      572.850159  1746700
# ...

# %% [markdown]
# ### df3

# %% [markdown]
# The movie dataset contains 918 rows and 11 columns.

# %%
# Highest Holywood Grossing Movies.csv
df3
# Out:
#      Unnamed: 0                                              Title  \
# 0             0  Star Wars: Episode VII - The Force Awakens (2015)
# 1             1                           Avengers: Endgame (2019)
# 2             2                                      Avatar (2009)
# 3             3                               Black Panther (2018)
# 4             4                      Avengers: Infinity War (2018)
# ..          ...                                                ...
# 913         913                                The Notebook (2004)
# 914         914                   Jimmy Neutron: Boy Genius (2001)
# 915         915                               Eat Pray Love (2010)
# 916         916                 The Texas Chainsaw Massacre (2003)
# 917         917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# ...

# %% [markdown]
# The first column contains the row index. I will drop it because it does not add any information to the data. The new df3 has 918 rows and 10 columns

# %%
# remove column
df3 = df3.drop(['Unnamed: 0'], axis = 1)

# print df3
df3
# Out:
#                                                  Title  \
# 0    Star Wars: Episode VII - The Force Awakens (2015)
# 1                             Avengers: Endgame (2019)
# 2                                        Avatar (2009)
# 3                                 Black Panther (2018)
# 4                        Avengers: Infinity War (2018)
# ..                                                 ...
# 913                                The Notebook (2004)
# 914                   Jimmy Neutron: Boy Genius (2001)
# 915                               Eat Pray Love (2010)
# 916                 The Texas Chainsaw Massacre (2003)
# 917                                   Zookeeper (2011)
#
#                                             Movie Info  \
# 0    As a new threat to the galaxy rises, Rey, a de...
# 1    After the devastating events of Avengers: Infi...
# 2    A paraplegic Marine dispatched to the moon Pan...
# 3    T'Challa, heir to the hidden but advanced king...
# ...

# %% [markdown]
# ### df4

# %% [markdown]
# The 4th dataframe contains 50 rows and 10 columns related to popular spotify songs.

# %%
df4
# Out:
#     id        artist_name                                         track_name  \
# 0    1     Olivia Rodrigo                                    drivers license
# 1    2          Lil Nas X                     MONTERO (Call Me By Your Name)
# 2    3      The Kid LAROI                          STAY (with Justin Bieber)
# 3    4     Olivia Rodrigo                                           good 4 u
# 4    5           Dua Lipa                          Levitating (feat. DaBaby)
# 5    6      Justin Bieber             Peaches (feat. Daniel Caesar & Giveon)
# 6    7           Doja Cat                           Kiss Me More (feat. SZA)
# 7    8         The Weeknd                                    Blinding Lights
# 8    9      Glass Animals                                         Heat Waves
# 9   10           Måneskin                                            Beggin'
# 10  11        Masked Wolf                             Astronaut In The Ocean
# ...

# %% [markdown]
# ## Question 3
#
# **Examine the shape of your data using the .shape command and the data types of
# your columns using .dtypes.**

# %% [markdown]
# ### df1

# %%
df1.shape
# Out:
# (51, 2)

# %%
df1.dtypes
# Out:
# df1 column data types:
# Sate                     object
# 2018 Mean Annual Wage    object
# dtype: object

# %% [markdown]
# ### df2

# %%
df2.shape
# Out:
# (1258, 7)

# %%
df2.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %% [markdown]
# ### df3

# %%
df3.shape
# Out:
# (918, 10)

# %%
df3.dtypes
# Out:
# Title                         object
# Movie Info                    object
# Distributor                   object
# Release Date                  object
# Domestic Sales (in $)          int64
# International Sales (in $)     int64
# World Sales (in $)             int64
# Genre                         object
# Movie Runtime                 object
# License                       object
# dtype: object

# %% [markdown]
# ### df4

# %%
df4.shape
# Out:
# (50, 18)

# %%
df4.dtypes
# Out:
# id                    int64
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# dtype: object

# %% [markdown]
# ## Question 4
#
# **Use .describe() on your data. What do you notice about your data? What does this
# command return?**

# %% [markdown]
# The .describe() function provides descriptive statistics that summarize central tenencies, dispersion, and shape of the dataset distribution.

# %% [markdown]
# ### df1
#
# The describe function returns counts as the columns are both classified as objects

# %%
df1.describe()
# Out:
#            Sate  2018 Mean Annual Wage
# count         51                    51
# unique        51                    49
# top     Alabama                 85,940
# freq           1                     2

# %% [markdown]
# ### df2
#
# The describe function returns mean, sd, min, max, etc. of all numeric data types.

# %%
df2.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean    842.065785   849.196733   834.607101   842.175733   842.175733
# std     224.688021   227.042283   222.565409   224.969453   224.969453
# min     491.942810   493.261566   484.891632   489.854309   489.854309
# 25%     645.425003   650.681763   637.150024   643.905029   643.905029
# 50%     795.364990   801.023010   790.855011   795.359985   795.359985
# 75%    1051.584992  1064.093719  1040.893494  1052.059967  1052.059967
# max    1274.000000  1289.270020  1266.295044  1287.579956  1287.579956
#
#              Volume
# count  1.258000e+03
# mean   1.750196e+06
# std    8.586929e+05
# min    5.272000e+05
# 25%    1.243325e+06
# 50%    1.531050e+06
# 75%    1.995025e+06
# max    1.116490e+07

# %% [markdown]
# ### df3
#
# Like df2, df3 numeric data types return the mean, sd, min, max, etc.

# %%
df3.describe()
# Out:
#        Domestic Sales (in $)  International Sales (in $)  World Sales (in $)
# count           9.180000e+02                9.180000e+02        9.180000e+02
# mean            1.677469e+08                2.301434e+08        3.968668e+08
# std             1.040360e+08                2.176011e+08        3.082629e+08
# min             8.036084e+07                2.600000e+02        8.160000e+07
# 25%             1.016071e+08                8.845620e+07        2.005564e+08
# 50%             1.321351e+08                1.638819e+08        3.019416e+08
# 75%             1.913905e+08                2.885577e+08        4.750718e+08
# max             9.366622e+08                2.086739e+09        2.847246e+09

# %% [markdown]
# ### df 4
#
# Numeric data types return numeric descriptive statistics.

# %%
df4.describe()
# Out:
#              id  popularity  danceability    energy        key   loudness  \
# count  50.00000   50.000000     50.000000  50.00000  50.000000  50.000000
# mean   25.50000   86.800000      0.685720   0.64636   5.180000  -5.903920
# std    14.57738    6.266203      0.124987   0.14712   3.868713   2.036948
# min     1.00000   67.000000      0.380000   0.33900   0.000000 -11.639000
# 25%    13.25000   85.250000      0.597750   0.54525   1.000000  -7.186250
# 50%    25.50000   88.000000      0.714500   0.65650   5.500000  -5.485500
# 75%    37.75000   90.000000      0.774500   0.76475   8.000000  -4.258500
# max    50.00000   95.000000      0.903000   0.89300  11.000000  -2.810000
#
#             mode  speechiness  acousticness  instrumentalness   liveness  \
# count  50.000000    50.000000     50.000000         50.000000  50.000000
# mean    0.620000     0.081374      0.253811          0.001606   0.182292
# std     0.490314     0.057164      0.235345          0.006425   0.137799
# ...

# %% [markdown]
# ## Question 5

# %% [markdown]
# **Use the .head() and .tail() command - what does this do?**

# %% [markdown]
# The .head() function returns the first i number of rows with a default of 5. The .tail() function returns the last i number of rows with a default of 5

# %% [markdown]
# ### df1

# %%
df1.head()
# Out:
#         Sate  2018 Mean Annual Wage
# 0    Alabama                 90,620
# 1      Alaska                99,180
# 2     Arizona                88,800
# 3    Arkansas                81,430
# 4  California                97,110

# %%
df1.tail()
# Out:
#             Sate  2018 Mean Annual Wage
# 46       Virginia                91,700
# 47     Washington                85,930
# 48  West Virginia                89,420
# 49      Wisconsin                85,200
# 50        Wyomimg                87,510

# %% [markdown]
# ### df2

# %%
df2.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 1  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 2  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 3  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 4  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 0  2213200
# 1  1974700
# 2  1746700
# 3  2243000
# 4  1317300

# %%
df2.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1253  2019-06-17  1086.280029  1099.180054  1086.280029  1092.500000
# 1254  2019-06-18  1109.689941  1116.390015  1098.989990  1103.599976
# 1255  2019-06-19  1105.599976  1107.000000  1093.479980  1102.329956
# 1256  2019-06-20  1119.989990  1120.119995  1104.739990  1111.420044
# 1257  2019-06-21  1109.239990  1124.109985  1108.079956  1121.880005
#
#         Adj Close   Volume
# 1253  1092.500000   941600
# 1254  1103.599976  1386700
# 1255  1102.329956  1338800
# 1256  1111.420044  1262000
# 1257  1121.880005  1930100

# %% [markdown]
# ### df3

# %%
df3.head()
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                               Black Panther (2018)
# 4                      Avengers: Infinity War (2018)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                            Distributor       Release Date  \
# 0  Walt Disney Studios Motion Pictures  December 16, 2015
# 1  Walt Disney Studios Motion Pictures     April 24, 2019
# 2                Twentieth Century Fox  December 16, 2009
# 3  Walt Disney Studios Motion Pictures                NaN
# ...

# %%
df3.tail()
# Out:
#                                   Title  \
# 913                 The Notebook (2004)
# 914    Jimmy Neutron: Boy Genius (2001)
# 915                Eat Pray Love (2010)
# 916  The Texas Chainsaw Massacre (2003)
# 917                    Zookeeper (2011)
#
#                                             Movie Info  \
# 913  A poor yet passionate young man falls in love ...
# 914  An eight-year-old boy genius and his friends m...
# 915  A married woman realizes how unhappy her marri...
# 916  After picking up a traumatized young hitchhike...
# 917  A group of zoo animals decide to break their c...
#
#                            Distributor       Release Date  \
# 913                    New Line Cinema      June 25, 2004
# 914                 Paramount Pictures  December 21, 2001
# 915  Sony Pictures Entertainment (SPE)    August 13, 2010
# 916                    New Line Cinema   October 17, 2003
# 917  Sony Pictures Entertainment (SPE)       July 6, 2011
#
# ...

# %% [markdown]
# ### df4

# %%
df4.head()
# Out:
#    id     artist_name                      track_name                track_id  \
# 0   1  Olivia Rodrigo                 drivers license  5wANPM4fQCJwkGd4rN57mH
# 1   2       Lil Nas X  MONTERO (Call Me By Your Name)  1SC5rEoYDGUK4NfG82494W
# 2   3   The Kid LAROI       STAY (with Justin Bieber)  5PjdY0CKGZdEuoNab3yDmX
# 3   4  Olivia Rodrigo                        good 4 u  4ZtFanR9U6ndgddUvNcjcG
# 4   5        Dua Lipa       Levitating (feat. DaBaby)  5nujrmhLynf4yMoMtj8AQF
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          92         0.561   0.431   10    -8.810     1       0.0578
# 1          90         0.593   0.503    8    -6.725     0       0.2200
# 2          92         0.591   0.764    1    -5.484     1       0.0483
# 3          95         0.563   0.664    9    -5.044     1       0.1540
# 4          89         0.702   0.825    6    -3.787     0       0.0601
#
# ...

# %%
df4.tail()
# Out:
#     id      artist_name                 track_name                track_id  \
# 45  46         J Balvin              Qué Más Pues?  6D2TCm4nf5nxAcdGJ7w3QP
# 46  47       Joel Corry  Head & Heart (feat. MNEK)  6cx06DFPPHchuUAcTxznu9
# 47  48    Ariana Grande                      34+35  6Im9k8u9iIzKMrmV7BWtlF
# 48  49       Tate McRae         you broke me first  45bE4HXI0AwGZXfZtMp8JR
# 49  50  Sebastian Yatra             Pareja Del Año  2rCbl9naJYhaxjLsfx88uM
#
#     popularity  danceability  energy  key  loudness  mode  speechiness  \
# 45          79         0.903   0.817    8    -3.972     1       0.0950
# 46          86         0.734   0.874    8    -3.158     1       0.0662
# 47          85         0.830   0.585    0    -6.476     1       0.0940
# 48          88         0.667   0.373    4    -9.389     1       0.0500
# 49          86         0.715   0.622    4    -5.102     0       0.0460
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %% [markdown]
# ## Extra Credit - Header information

# %% [markdown]
# ### 1. Choose one of your datasets and remove the header information. (Can delete the row in excel, etc..)
#
# ### 2. Import the data into your environment using pandas. Display the .head() of your data showing no header information.

# %%
# load data with no headers
df2_no_header = pd.read_csv('https://raw.githubusercontent.com/data602sps/datasetspractice/main/GOOG.csv', header = None)

# remove header row
df2_no_header = df2_no_header.drop(0)

# print df
df2_no_header.head()
# Out:
#             0           1           2           3           4           5  \
# 1  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 2  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 3  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 4  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 5  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#          6
# 1  2213200
# 2  1974700
# 3  1746700
# 4  2243000
# 5  1317300

# %% [markdown]
# ### 3. Using pandas, update the dataset to include the header information. Display the updated data using .head().

# %%
# add back headers
df2_no_header.columns = ["Date", "Open", "High", "Low", "Close", "Adj_Close", "Volume"]

# print df
df2_no_header.head()
# Out:
#          Date        Open        High         Low       Close   Adj_Close  \
# 1  2014-06-24  562.099304  569.514526  557.942139  561.532410  561.532410
# 2  2014-06-25  562.168884  576.788513  562.129089  575.485657  575.485657
# 3  2014-06-26  577.822815  579.264893  568.722839  572.850159  572.850159
# 4  2014-06-27  574.023682  576.698975  570.662170  574.083374  574.083374
# 5  2014-06-30  575.495605  576.400635  571.606995  572.134094  572.134094
#
#     Volume
# 1  2213200
# 2  1974700
# 3  1746700
# 4  2243000
# 5  1317300
